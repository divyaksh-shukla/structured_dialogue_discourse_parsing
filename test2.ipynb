# %%
import transformers
from transformers import pipeline
import pandas as pd
import numpy as np
from pathlib import Path
import os

# %%
convin_data_path = Path('convin_data/convin_complete_dataset_no_embedding_translated.pkl')

df = pd.read_pickle(convin_data_path)

# %%
df.head()
# Out:
#      domain domain_batch dialogue_id utt_id  \
# 0  stashfin       batch1       58105      1
# 1  stashfin       batch1       58105      2
# 2  stashfin       batch1       58105      3
# 3  stashfin       batch1       58105      4
# 4  stashfin       batch1       58105      5
#
#                                     roman_transcript  \
# 0  apane jis vyakti ko call kia hai vo abhi dusar...
# 1  hello hello good afternoon sir sube khan bat k...
# 2  ha ha sir main stashfin se khushi bat kar rahi...
# 3  payment nahi kar raha hu matalab matalab apane...
# 4  mera kitane ka payment hua hai wait abhi batat...
#
#                                    native_transcript  \
# 0  आपने जिस vyakti को call kia है वो अभी दूसरे ca...
# 1  hello hello good afternoon sir सूबे khan बात क...
# 2  ha ha sir मैं stashfin से खुशी बात कर रही हूं ...
# 3  payment नही कर रहा हु मतलब मतलब आपने stashfin ...
# 4    मेरा कितने का payment हुआ है wait अभी बताती हूं
#
# ...
